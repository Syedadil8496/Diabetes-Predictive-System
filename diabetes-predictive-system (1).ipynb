# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Import required libraries

# %%
#To avoid unnecessary warnings messages
import warnings
warnings.filterwarnings('ignore')

#Visualisation libraries
import seaborn as sns
import matplotlib.pyplot as plt

#To scale our data
from sklearn.preprocessing import StandardScaler

#To split the data into training and testing set
from sklearn.model_selection import train_test_split

#Classification model- Support Vector Machine
from sklearn.svm import SVC

#Classification model performance metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score

# %%
df=pd.read_csv(r'E:\intership project\diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Number of Rows and columns

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # Data Description

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
sns.pairplot(df,hue='Outcome')

# %% [markdown]
# # Data Correlation

# %%
plt.figure(figsize=(8,2))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(20,8))
for i,col in enumerate(df.iloc[:,:-1]):
    plt.subplot(2,4,i+1)
    sns.kdeplot(df[col],shade=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating the DataFrame
df=pd.read_csv(r'E:\intership project\diabetes.csv')

# Creating a barplot for one of the columns (e.g., "Glucose")
plt.figure(figsize=(10, 6))
plt.bar(df.index, df["Glucose"], color='skyblue', alpha=0.7)
plt.title("Glucose Levels for Patients", fontsize=16)
plt.xlabel("Patient Index", fontsize=12)
plt.ylabel("Glucose Level", fontsize=12)
plt.xticks(df.index, labels=df.index)
plt.grid(axis='y', linestyle='--', alpha=0.9)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Loading the DataFrame
df = pd.read_csv(r'E:\intership project\diabetes.csv')

# Selecting columns for comparison
x = df.index
glucose = df["Glucose"]
blood_pressure = df["BloodPressure"]

# Bar width and positions
bar_width = 0.4
x_indexes = np.arange(len(x))

# Plotting grouped bar chart
plt.figure(figsize=(12, 6))
plt.bar(x_indexes - bar_width / 2, glucose, width=bar_width, label="Glucose", color="skyblue")
plt.bar(x_indexes + bar_width / 2, blood_pressure, width=bar_width, label="Blood Pressure", color="salmon")

# Adding labels, title, and legend
plt.title("Comparison of Glucose and Blood Pressure Levels", fontsize=16)
plt.xlabel("Patient Index", fontsize=12)
plt.ylabel("Levels", fontsize=12)
plt.xticks(ticks=x_indexes, labels=x, rotation=45)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file
df = pd.read_csv(r'E:\intership project\diabetes.csv')

# Take a sample of 10 rows for visualization
df_sample = df.head(10)

# Selecting columns for comparison
x = df_sample.index
glucose = df_sample["Glucose"]
blood_pressure = df_sample["BloodPressure"]

# Grouped Bar Chart
bar_width = 0.4
x_indexes = np.arange(len(x))

plt.figure(figsize=(12, 6))
plt.bar(x_indexes - bar_width / 2, glucose, width=bar_width, label="Glucose", color="skyblue")
plt.bar(x_indexes + bar_width / 2, blood_pressure, width=bar_width, label="Blood Pressure", color="salmon")

# Adding labels, title, and legend
plt.title("Comparison of Glucose and Blood Pressure Levels", fontsize=16)
plt.xlabel("Patient Index", fontsize=12)
plt.ylabel("Levels", fontsize=12)
plt.xticks(ticks=x_indexes, labels=x, rotation=45)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# Optional: Line Chart
plt.figure(figsize=(12, 6))
plt.plot(x, glucose, label="Glucose", color="blue", marker="o", linestyle="-", linewidth=2)
plt.plot(x, blood_pressure, label="Blood Pressure", color="orange", marker="s", linestyle="--", linewidth=2)

# Adding labels, title, and legend
plt.title("Line Chart: Glucose vs Blood Pressure", fontsize=16)
plt.xlabel("Patient Index", fontsize=12)
plt.ylabel("Levels", fontsize=12)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loading the DataFrame
df = pd.read_csv(r'E:\intership project\diabetes.csv')

# Plotting line graph for Glucose and BloodPressure
plt.figure(figsize=(12, 6))
plt.plot(df.index, df["Glucose"], label="Glucose", color='blue', linestyle='-', linewidth=2)


# Adding title and labels
plt.title("Glucose and Blood Pressure Levels for Patients", fontsize=16)
plt.xlabel("Patient Index", fontsize=12)
plt.ylabel("Levels", fontsize=12)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loading the DataFrame
df = pd.read_csv(r'E:\intership project\diabetes.csv')

# Counting the occurrences of each outcome
outcome_counts = df['Outcome'].value_counts()

# Pie chart for Outcome distribution
plt.figure(figsize=(8, 8))
plt.pie(outcome_counts, 
        labels=["Non-Diabetic (0)", "Diabetic (1)"], 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=['lightblue', 'salmon'], 
        explode=[0, 0.1])

# Adding title
plt.title("Diabetes Outcome Distribution", fontsize=16)
plt.show()

# %% [markdown]
# # Target Grouped data mean

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'E:\intership project\diabetes.csv')

# Selecting features for pairplot (e.g., first few numerical columns)
features = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "BMI", "Age", "Outcome"]

# Pairplot
sns.set(style="whitegrid")
pair_plot = sns.pairplot(df[features], hue="Outcome", palette="husl", diag_kind="kde")

# Show the plot
pair_plot.fig.suptitle("Feature Pair Plot", y=1.02)  # Adding a title
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loading the DataFrame
df = pd.read_csv(r'E:\intership project\diabetes.csv')

# Features to visualize with a box plot
features = ['Glucose', 'BloodPressure', 'BMI', 'Age']

# Setting up the plot
plt.figure(figsize=(12, 6))
box = plt.boxplot([df[feature] for feature in features], 
                  patch_artist=True,  # Enables custom coloring
                  labels=features)

# Colors for the boxes
colors = ['lightblue', 'salmon', 'lightgreen', 'orange']

# Customizing the box plot with colors
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Adding title and labels
plt.title("Box Plot for Selected Features", fontsize=16)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Values", fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)  # Remove the grid if you prefer cleaner visuals

plt.show()

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# # Target Value counts- Imbalanced data

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# # Splitting dataset into features and target

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

# %% [markdown]
# # Scaling the data

# %%
ss=StandardScaler()
ss.fit(x)
# Out:
# StandardScaler()

# %%
x=ss.transform(x)

# %%
x
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %% [markdown]
# # Splitting dataset further into training and testing data

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=200,test_size=0.2,stratify=y)

# %% [markdown]
# # Model Evaluation

# %%
model=SVC(kernel='linear',C=10.0)

model.fit(xtrain,ytrain)
ypred=model.predict(xtest) 
ac=accuracy_score(ytest,ypred) 
cm=confusion_matrix(ytest,ypred) 
cr=classification_report(ytest,ypred) 
train=model.score(xtrain,ytrain) 
test=model.score(xtest,ytest)
    
print(f'{model} Accuracy:{ac}\n{cm}\n{cr}\nTraining Accuracy: {train*100}\nTesting Accuracy: {test*100}')
# Out:
# SVC(C=10.0, kernel='linear') Accuracy:0.8051948051948052
# [[89 11]
#  [19 35]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86       100
#            1       0.76      0.65      0.70        54
#
#     accuracy                           0.81       154
#    macro avg       0.79      0.77      0.78       154
# weighted avg       0.80      0.81      0.80       154
#
# Training Accuracy: 76.8729641693811
# Testing Accuracy: 80.51948051948052

# %% [markdown]
# # Model Deployment- Predictive System

# %%
def prediction(input_data=()):
    #Converting to numpy array
    array_input_data=np.asarray(input_data)
    
    #Reshaping to tell the model we want prediction for 1 instance
    x=array_input_data.reshape(1,-1)
    
    #Standardising data
    standard_x=ss.transform(x)
    
    #Predicting 
    p=model.predict(standard_x)
    
    #Returning the prediction
    if p==0:
        print('Patient is not Diabetic')
    else:
        print('Patient is Diabetic')
    
    return p

# %%
prediction([4,110,92,0,0,37.6,0.191,30])
# Out:
# Patient is not Diabetic
# array([0], dtype=int64)

# %%
prediction([6,110,92,0,0,86.6,0.191,60])
# Out:
# Patient is Diabetic
# array([1], dtype=int64)

# %%
def predictions(input_data=()):
    #Converting to numpy array
    array_input_data=np.asarray(input_data)
    
  
    
    #Reshaping to tell the model we want prediction for 1 instance
    x=array_input_data.reshape(1,-1)
    
   
    
    #Predicting 
    p=model.predict(x)
    
    #Returning the prediction
    if p==0:
        print('Patient is not Diabetic')
    else:
        print('Patient is Diabetic')
    
    return p

# %%
predictions([6,110,92,0,0,86.6,0.191,60])
# Out:
# Patient is Diabetic
# array([1], dtype=int64)
